# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import datetime
from matplotlib import style
style.use('default')

from datetime import timedelta
import glob

# %%
# Load and preprocess electricity demand data
data_path = "Data/"
files = glob.glob(data_path + "Native_*.xlsx")
df = pd.read_excel(files[4])

# %%
files
# Out:
# ['Data\\Native_Load_2018.xlsx',
#  'Data\\Native_Load_2019.xlsx',
#  'Data\\Native_Load_2020.xlsx',
#  'Data\\Native_Load_2021.xlsx',
#  'Data\\Native_Load_2022.xlsx',
#  'Data\\Native_Load_2023.xlsx',
#  'Data\\Native_Load_2024.xlsx']

# %%
df.head()
# Out:
#         Hour Ending         COAST         EAST        FWEST       NORTH  \
# 0  01/01/2022 01:00  12054.939199  1302.296674  4161.193625  757.843076
# 1  01/01/2022 02:00  11793.290315  1259.355201  4147.907009  737.236591
# 2  01/01/2022 03:00  11460.841252  1210.287905  4156.412366  725.610502
# 3  01/01/2022 04:00  11244.980243  1179.311517  4149.811722  717.420214
# 4  01/01/2022 05:00  11073.085585  1171.841803  4140.619028  719.178247
#
#          NCENT        SOUTH        SCENT        WEST         ERCOT
# 0  9676.300802  3172.878316  5908.031505  973.455700  38006.938896
# 1  9307.126712  3123.318608  5708.512022  959.775908  37036.522365
# 2  8920.424552  3003.396233  5463.522829  941.112359  35881.607998
# 3  8678.807826  2898.097471  5255.252404  920.373708  35044.055105
# 4  8573.370608  2825.100402  5164.172158  918.203309  34585.571140

# %%
df.count()
# Out:
# Hour Ending    8760
# COAST          8760
# EAST           8760
# FWEST          8760
# NORTH          8760
# NCENT          8760
# SOUTH          8760
# SCENT          8760
# WEST           8760
# ERCOT          8760
# dtype: int64

# %%
def csvfileread(file):
    skiprows = []
    from datetime import timedelta
    import pandas as pd
    df = pd.read_excel(file, header=0, skiprows=skiprows)
    df.columns = [c.replace(' ', '_') for c in df.columns]
    df = df.rename(columns={'Hour_Ending': 'Timestamp'})
    

    df['datetime_zero'] = df['Timestamp'].str.replace('24:00', '0:00')
    df['datetime_er'] = pd.to_datetime(df['datetime_zero'], format='%m/%d/%Y %H:%M', errors='coerce')
    df = df.loc[~df.datetime_er.isnull()]
    selrow = df['Timestamp'].str.contains('24:00')
    df['datetime_obj'] = df['datetime_er'] + selrow * timedelta(days=1)

    df0 = pd.DataFrame()
    df0['ERCOT'] = df['ERCOT'].copy()
    df0['datetime_obj'] = df['datetime_obj'].copy()

    return df0

# %%
filenames = glob.glob(data_path + "Native_*.xlsx")
for i, file in enumerate(filenames):
    print(i)
    if i == 0:
        df1 = csvfileread(file)
        df_load = df1
    else:
        df1 = csvfileread(file)
        df_load = pd.concat([df_load, df1], axis=0)

    df_load= df_load.sort_index()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
df_load
# Out:
#              ERCOT        datetime_obj
# 0     50567.069682 2018-01-01 01:00:00
# 0     38006.938896 2022-01-01 01:00:00
# 0     37081.443439 2019-01-01 01:00:00
# 0     41223.480177 2024-01-01 01:00:00
# 0     36824.115099 2020-01-01 01:00:00
# ...            ...                 ...
# 8781  46754.840878 2020-12-31 22:00:00
# 8782  45475.412261 2020-12-31 23:00:00
# 8782  44779.606498 2024-12-31 23:00:00
# 8783  44503.547341 2021-01-01 00:00:00
# 8783  43892.434849 2025-01-01 00:00:00
#
# [61360 rows x 2 columns]

# %%
df_load = df_load.rename(columns={'datetime_obj': 'timestamp'})
df_load['timestamp'] = pd.to_datetime(df_load['timestamp'])
df_load=df_load.set_index('timestamp').sort_index()
df_load = df_load[~df_load.index.duplicated(keep='first')]
plt.plot(df_load.ERCOT, '.')

# %%
df_load
# Out:
#                             ERCOT
# timestamp
# 2018-01-01 01:00:00  50567.069682
# 2018-01-01 02:00:00  50617.087977
# 2018-01-01 03:00:00  50694.300087
# 2018-01-01 04:00:00  50999.591693
# 2018-01-01 05:00:00  51723.732017
# ...                           ...
# 2024-12-31 20:00:00  47619.264355
# 2024-12-31 21:00:00  46737.678611
# 2024-12-31 22:00:00  45775.649767
# 2024-12-31 23:00:00  44779.606498
# 2025-01-01 00:00:00  43892.434849
#
# [61360 rows x 1 columns]

# %%
df_load=df_load.resample('60min').mean()

# %%
df_load.to_csv(data_path+'Native_Load_all.csv')

# %%
# Load data
filename = data_path + '/Native_Load_all.csv'
df_load= pd.read_csv(filename)

# %%
df_load
# Out:
#                  timestamp         ERCOT
# 0      2018-01-01 01:00:00  50567.069682
# 1      2018-01-01 02:00:00  50617.087977
# 2      2018-01-01 03:00:00  50694.300087
# 3      2018-01-01 04:00:00  50999.591693
# 4      2018-01-01 05:00:00  51723.732017
# ...                    ...           ...
# 61363  2024-12-31 20:00:00  47619.264355
# 61364  2024-12-31 21:00:00  46737.678611
# 61365  2024-12-31 22:00:00  45775.649767
# 61366  2024-12-31 23:00:00  44779.606498
# 61367  2025-01-01 00:00:00  43892.434849
#
# [61368 rows x 2 columns]

# %% [markdown]
# ## Load different temperature and weather data

# %%
data_path
# Out:
# 'Data/'

# %%
# Load and preprocess electricity demand data
file_paths = glob.glob(data_path + "Weather data/"+ "asos_hourly_*.csv")

# %%
file_paths
# Out:
# ['Data/Weather data\\asos_hourly_BKS.csv',
#  'Data/Weather data\\asos_hourly_JDD.csv',
#  'Data/Weather data\\asos_hourly_TME.csv']

# %%
# Define a function to read and rename columns of a single file
def read_and_rename(file_path, suffix):
    print(suffix)
    df = pd.read_csv(file_path)
    df['timestamp'] = pd.to_datetime(df['timestamp'])  
    df = df.rename(columns=lambda x: f"{x}_{suffix}" if x != 'timestamp' else x)
    index=df[f"tmpc_{suffix}"] < -20
    df[f"tmpc_{suffix}"][index]=np.nan

    index=df[f"sped_{suffix}"] > 50
    df[f"sped_{suffix}"][index]=np.nan

    return df

# %%
df
# Out:
#            Hour Ending         COAST         EAST        FWEST       NORTH  \
# 0     01/01/2022 01:00  12054.939199  1302.296674  4161.193625  757.843076
# 1     01/01/2022 02:00  11793.290315  1259.355201  4147.907009  737.236591
# 2     01/01/2022 03:00  11460.841252  1210.287905  4156.412366  725.610502
# 3     01/01/2022 04:00  11244.980243  1179.311517  4149.811722  717.420214
# 4     01/01/2022 05:00  11073.085585  1171.841803  4140.619028  719.178247
# ...                ...           ...          ...          ...         ...
# 8755  12/31/2022 20:00  10247.562908  1407.683729  5218.996613  938.901362
# 8756  12/31/2022 21:00   9887.676773  1362.637978  5217.501326  963.913723
# 8757  12/31/2022 22:00   9572.382483  1327.298817  5235.313653  949.798259
# 8758  12/31/2022 23:00   9258.586996  1237.913479  5226.630655  928.929373
# 8759  12/31/2022 24:00   8999.616362  1216.122804  5193.649360  898.505355
#
#              NCENT        SOUTH        SCENT         WEST         ERCOT
# 0      9676.300802  3172.878316  5908.031505   973.455700  38006.938896
# 1      9307.126712  3123.318608  5708.512022   959.775908  37036.522365
# 2      8920.424552  3003.396233  5463.522829   941.112359  35881.607998
# 3      8678.807826  2898.097471  5255.252404   920.373708  35044.055105
# 4      8573.370608  2825.100402  5164.172158   918.203309  34585.571140
# ...            ...          ...          ...          ...           ...
# 8755  11656.958118  3452.868539  6833.564855  1125.338906  40881.875030
# 8756  11242.914145  3228.129723  6629.002740  1103.919231  39635.695638
# 8757  10944.369192  3078.543411  6413.225604  1084.122587  38605.054006
# 8758  10508.050809  3020.175467  6161.413424  1058.601615  37400.301819
# 8759  10139.198578  2951.500773  5957.229897  1043.484788  36399.307918
#
# [8760 rows x 10 columns]

# %%
# Read and rename columns of all files
dfs = [read_and_rename(file_paths[i], i+1) for i in range(len(file_paths))]
# Out:
# 1
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"tmpc_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"tmpc_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"sped_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"sped_{suffix}"][index]=np.nan
# 2
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"tmpc_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"tmpc_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"sped_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"sped_{suffix}"][index]=np.nan
# 3
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"tmpc_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"tmpc_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[f"sped_{suffix}"][index]=np.nan
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\1779252998.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"sped_{suffix}"][index]=np.nan

# %%
# Merge all dataframes on 'timestamp'
df_weather = dfs[0]
for df in dfs[1:]:
    df_weather = pd.merge(df_weather, df, on='timestamp', how='outer')

# %%
# Display the merged dataframe
df_weather
#merged_df.head()
# Out:
#                  timestamp  tmpc_1  relh_1  sped_1  feel_1  p01m_1  tmpc_2  \
# 0      2017-01-01 00:15:00   15.28   95.80    0.00    59.5     0.0   13.00
# 1      2017-01-01 00:35:00   15.28   95.80    0.00    59.5     0.0   13.00
# 2      2017-01-01 00:55:00   15.56   96.15    8.05    59.9     0.0   13.00
# 3      2017-01-01 01:15:00   15.78   95.81    3.45    60.4     0.0   13.00
# 4      2017-01-01 01:35:00   16.00   95.14    0.00    60.8     0.0   13.00
# ...                    ...     ...     ...     ...     ...     ...     ...
# 214608 2025-01-03 22:35:00   17.11  100.00    4.60    62.8     0.0   12.78
# 214609 2025-01-03 22:55:00   17.11  100.00    4.60    62.8     0.0   12.78
# 214610 2025-01-03 23:15:00   17.11  100.00    4.60    62.8     0.0   12.61
# 214611 2025-01-03 23:35:00   17.11  100.00    4.60    62.8     0.0   12.50
# 214612 2025-01-03 23:55:00   17.11  100.00    0.00    62.8     0.0   12.50
#
#         relh_2  sped_2  feel_2  p01m_2  tmpc_3  relh_3  sped_3  feel_3  p01m_3
# 0       100.00    0.00    55.4     0.0    18.0   100.0     0.0    64.4     0.0
# 1       100.00    0.00    55.4     0.0    18.0   100.0     0.0    64.4     0.0
# 2       100.00    3.45    55.4     0.0    18.0   100.0     0.0    64.4     0.0
# 3       100.00    0.00    55.4     0.0    18.0   100.0     0.0    64.4     0.0
# 4       100.00    0.00    55.4     0.0    18.0   100.0     0.0    64.4     0.0
# ...        ...     ...     ...     ...     ...     ...     ...     ...     ...
# 214608   66.36    3.45    55.0     0.0     NaN     NaN     NaN     NaN     NaN
# 214609   66.36    3.45    55.0     0.0     NaN     NaN     NaN     NaN     NaN
# 214610   67.60    0.00    54.7     0.0     NaN     NaN     NaN     NaN     NaN
# 214611   68.09    3.45    54.5     0.0     NaN     NaN     NaN     NaN     NaN
# 214612   68.09    4.60    54.5     0.0     NaN     NaN     NaN     NaN     NaN
#
# [214613 rows x 16 columns]

# %%
df_load['timestamp'] = pd.to_datetime(df_load['timestamp'])
df_weather['timestamp'] = pd.to_datetime(df_weather['timestamp'])

# %%
df_weather.to_csv(data_path+ 'Weather data/' + 'asos_weather_data.csv')

# %%
fig=plt.figure(figsize=(16,6), linewidth=3)
plt.plot(df_weather.set_index('timestamp')[['tmpc_1', 'tmpc_2', 'tmpc_3']],'.')
plt.legend()
# Out:
# C:\Users\sajib\AppData\Local\Temp\ipykernel_2900\2769681222.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_weather.set_index('timestamp', inplace=True)

# %%
df_weather
# Out:
#                      tmpc_1  relh_1  sped_1  feel_1  p01m_1  tmpc_2  relh_2  \
# timestamp
# 2017-01-01 00:15:00   15.28   95.80    0.00    59.5     0.0   13.00  100.00
# 2017-01-01 00:35:00   15.28   95.80    0.00    59.5     0.0   13.00  100.00
# 2017-01-01 00:55:00   15.56   96.15    8.05    59.9     0.0   13.00  100.00
# 2017-01-01 01:15:00   15.78   95.81    3.45    60.4     0.0   13.00  100.00
# 2017-01-01 01:35:00   16.00   95.14    0.00    60.8     0.0   13.00  100.00
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2025-01-03 22:35:00   17.11  100.00    4.60    62.8     0.0   12.78   66.36
# 2025-01-03 22:55:00   17.11  100.00    4.60    62.8     0.0   12.78   66.36
# 2025-01-03 23:15:00   17.11  100.00    4.60    62.8     0.0   12.61   67.60
# 2025-01-03 23:35:00   17.11  100.00    4.60    62.8     0.0   12.50   68.09
# 2025-01-03 23:55:00   17.11  100.00    0.00    62.8     0.0   12.50   68.09
#
#                      sped_2  feel_2  p01m_2  tmpc_3  relh_3  sped_3  feel_3  \
# timestamp
# 2017-01-01 00:15:00    0.00    55.4     0.0    18.0   100.0     0.0    64.4
# 2017-01-01 00:35:00    0.00    55.4     0.0    18.0   100.0     0.0    64.4
# 2017-01-01 00:55:00    3.45    55.4     0.0    18.0   100.0     0.0    64.4
# 2017-01-01 01:15:00    0.00    55.4     0.0    18.0   100.0     0.0    64.4
# 2017-01-01 01:35:00    0.00    55.4     0.0    18.0   100.0     0.0    64.4
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2025-01-03 22:35:00    3.45    55.0     0.0     NaN     NaN     NaN     NaN
# 2025-01-03 22:55:00    3.45    55.0     0.0     NaN     NaN     NaN     NaN
# 2025-01-03 23:15:00    0.00    54.7     0.0     NaN     NaN     NaN     NaN
# 2025-01-03 23:35:00    3.45    54.5     0.0     NaN     NaN     NaN     NaN
# 2025-01-03 23:55:00    4.60    54.5     0.0     NaN     NaN     NaN     NaN
#
#                      p01m_3
# timestamp
# 2017-01-01 00:15:00     0.0
# 2017-01-01 00:35:00     0.0
# 2017-01-01 00:55:00     0.0
# 2017-01-01 01:15:00     0.0
# 2017-01-01 01:35:00     0.0
# ...                     ...
# 2025-01-03 22:35:00     NaN
# 2025-01-03 22:55:00     NaN
# 2025-01-03 23:15:00     NaN
# 2025-01-03 23:35:00     NaN
# 2025-01-03 23:55:00     NaN
#
# [214613 rows x 15 columns]

# %%
df_weather=df_weather.resample('60min').mean()

temp1 = df_weather[['tmpc_1', 'tmpc_2','tmpc_3']].mean(axis=1)
plt.plot(temp1)

# %%
df_weather
# Out:
#                         tmpc_1      relh_1    sped_1     feel_1  p01m_1  \
# timestamp
# 2017-01-01 00:00:00  15.373333   95.916667  2.683333  59.633333     0.0
# 2017-01-01 01:00:00  15.853333   95.360000  2.300000  60.533333     0.0
# 2017-01-01 02:00:00  15.926667   95.820000  0.000000  60.666667     0.0
# 2017-01-01 03:00:00  16.000000   96.393333  0.000000  60.800000     0.0
# 2017-01-01 04:00:00  16.963333   93.106667  5.750000  62.533333     0.0
# ...                        ...         ...       ...        ...     ...
# 2025-01-03 19:00:00  18.630000   89.490000  4.983333  65.533333     0.0
# 2025-01-03 20:00:00  17.500000  100.000000  5.750000  63.500000     0.0
# 2025-01-03 21:00:00  17.183333  100.000000  5.366667  62.933333     0.0
# 2025-01-03 22:00:00  17.110000  100.000000  4.983333  62.800000     0.0
# 2025-01-03 23:00:00  17.110000  100.000000  3.066667  62.800000     0.0
#
#                         tmpc_2      relh_2    sped_2     feel_2  p01m_2  \
# timestamp
# 2017-01-01 00:00:00  13.000000  100.000000  1.150000  55.400000     0.0
# 2017-01-01 01:00:00  13.333333   97.896667  0.000000  56.000000     0.0
# 2017-01-01 02:00:00  14.000000   95.793333  2.300000  57.200000     0.0
# 2017-01-01 03:00:00  14.000000  100.000000  3.450000  57.200000     0.0
# 2017-01-01 04:00:00  14.000000   95.793333  1.150000  57.200000     0.0
# ...                        ...         ...       ...        ...     ...
# 2025-01-03 19:00:00  10.760000   79.906667  0.000000  51.366667     0.0
# 2025-01-03 20:00:00  12.370000   71.076667  1.150000  54.266667     0.0
# 2025-01-03 21:00:00  12.686667   68.320000  0.000000  54.833333     0.0
# 2025-01-03 22:00:00  12.780000   66.530000  3.450000  55.000000     0.0
# 2025-01-03 23:00:00  12.536667   67.926667  2.683333  54.566667     0.0
#
#                         tmpc_3  relh_3  sped_3  feel_3  p01m_3
# timestamp
# 2017-01-01 00:00:00  18.000000   100.0    0.00    64.4     0.0
# 2017-01-01 01:00:00  18.000000   100.0    0.00    64.4     0.0
# 2017-01-01 02:00:00  17.333333   100.0    0.00    63.2     0.0
# 2017-01-01 03:00:00  17.000000   100.0    1.15    62.6     0.0
# 2017-01-01 04:00:00  17.000000   100.0    0.00    62.6     0.0
# ...                        ...     ...     ...     ...     ...
# 2025-01-03 19:00:00        NaN     NaN     NaN     NaN     NaN
# 2025-01-03 20:00:00        NaN     NaN     NaN     NaN     NaN
# 2025-01-03 21:00:00        NaN     NaN     NaN     NaN     NaN
# 2025-01-03 22:00:00        NaN     NaN     NaN     NaN     NaN
# 2025-01-03 23:00:00        NaN     NaN     NaN     NaN     NaN
#
# [70200 rows x 15 columns]
